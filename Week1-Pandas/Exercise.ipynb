# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
import pandas as pd
import numpy as np
df = pd.read_csv('data/listings.csv', sep=',')

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#     * Count the amout of names each time appears.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`
#
#
# Challenge:
# * Listings with the word brownstone in the name (hint to come, might move this one later if needed)
#     * hint... build a function to check for 'brownstone' and apply that function OR  `df.name.str.????`

# %%
# 1. How many listings are there with a price less than 100? 
select_condition = df['price'] < 100
print("Listings less than 100: "+ str(len(df[select_condition])))
# Out:
# Listings less than 100: 22778

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn of less than $100.
select_condition2 = df['neighbourhood_group'] == "Brooklyn"

df_bk = df[select_condition2]
print("Listings in Brooklyn: "+ str(len(df[select_condition2])))
# Out:
# Listings in Brooklyn: 18632

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

print("Listings in Brooklyn & less than 100: "+ str(len(df[select_condition & select_condition2])))
# Out:
# Listings in Brooklyn & less than 100: 10473

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
list_hosts = ["Michael", "David", "John", "Daniel"]

condition = df.host_name.isin(list_hosts)
df["host_name"][condition].value_counts()
# Out:
# Michael    387
# David      348
# John       270
# Daniel     253
# Name: host_name, dtype: int64

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before.
select_condition = df["neighbourhood"] == "Williamsburg"
df["adjusted_price"] = np.where(select_condition, df["price"]+100 , df["price"])
df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# 5          5203                 Cozy Clean Guest Room - Family Apt       7490
# 6          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 7          5552            Spacious river view in the West Village       8380
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 9          6021  Wonderful Guest Bedroom in Manhattan CENTRAL PARK      11528
# 10         6090                      West Village Nest - Superhost      11975
# 11         6848                   Only 2 stops to Manhattan studio      15991
# 12         6990               UES Beautiful Blue Room / 2 Bedrooms      16800
# 13         7097       Perfect for Your Parents + Garden; Germ-Free      17571
# 14         7750          2 Furnished bedrooms next to Central Park      17985
# 15         7801                   Sweet and Spacious Brooklyn Loft      21207
# 16         8490             MAISON DES SIRENES1,bohemian apartment      25183
# 17         8505                 Sunny Bedroom Across Prospect Park      25326
# 18         8700  Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 19         9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# 20         9704                Spacious 1 bedroom in luxe building      32045
# 21        10452                              Large B&B Style rooms      35935
# 22        10962            Lovely Room 2; Garden; Best area, Legal       9744
# 23        11943                          Country space in the city      45445
# 24        12048                LowerEastSide apt share shortterm 1       7549
# 25        12192                                ENJOY Downtown NYC!      46978
# 26        12343                                 BEST BET IN HARLEM      47727
# 27        12627  Entire apartment in central Brooklyn neighborh...      49670
# 28        12937  1 Stop fr. Manhattan! Private Suite,Landmark B...      50124
# 29        12940                 Charming Brownstone 3 - Near PRATT      50148
# ...         ...                                                ...        ...
# 46497  44767959           A very quiet and crime free neighborhood  289154444
# 46498  44768081  Home is where the heart is . Sharing mine with...  215027230
# 46499  44769471     Luxury 2 Bedroom 2 Bath Townhouse in Manhattan    1556814
# 46500  44770013                  Luxury Building. Panoramic Views!   17532419
# 46501  44789250                            Private Room Chelsea 4A  241889662
# 46502  44789815                            Private Room Chelsea 3D  241889662
# 46503  44790395                            Private Room Chelsea 2D  241889662
# 46504  44791688              1 bdrm apt. on Orchard and Broome LES    8737911
# 46505  44791984       very convenient area right next to JMZ train   86766592
# 46506  44792997                     The Best of the Upper Westside  362369539
# 46507  44795562       Spacious Brooklyn Home with Private Roofdeck    4035493
# 46508  44797527    Long-Term: Furnished Apt in Nolita w/ Amenities   19448640
# 46509  44798678     Sonder *Private 1BR Apartment* at Battery Park  219517861
# 46510  44798876  Unique & beautiful design! Skylights-Washer/dryer  143513836
# 46511  44799007  Sonder at Battery Park | Studio with Weekly Di...  219517861
# 46512  44799074  Sonder *Weekly Discounts* ADA Studio at Batter...  219517861
# 46513  44800276        Williamsburg 1 Bedroom, Spacious and Classy  361034257
# 46514  44801333                                        Like a home  244745075
# 46515  44801335                     Bright & Cozy Nolita 1 Bedroom  361814116
# 46516  44801958        Luxury building apartment in FiDi Manhattan   82696573
# 46517  44802032                  A very large room in Williamsburg  213793805
# 46518  44802224  Unique & beautiful design! Skylights-Washer/dryer  143513836
# 46519  44803201  1200 SF Duplex apt in an old shoe factory/ mon...     921746
# 46520  44804690    Cozy place, peaceful,  friendly and affordable.  362419479
# 46521  44807338                  Modern luxury Chelsea one bedroom   36370873
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
#                     host_name neighbourhood_group              neighbourhood  \
# 0                    Jennifer           Manhattan                    Midtown
# 1                 LisaRoxanne            Brooklyn               Clinton Hill
# 2                       Garon            Brooklyn         Bedford-Stuyvesant
# 3                     Rebecca            Brooklyn                Sunset Park
# 4                    Shunichi           Manhattan             Hell's Kitchen
# 5                   MaryEllen           Manhattan            Upper West Side
# 6                         Ben           Manhattan                  Chinatown
# 7                       Maria           Manhattan               West Village
# 8                      Laurie            Brooklyn                South Slope
# 9                     Claudio           Manhattan            Upper West Side
# 10                      Alina           Manhattan               West Village
# 11              Allen & Irina            Brooklyn               Williamsburg
# 12                        Cyn           Manhattan                East Harlem
# 13                       Jane            Brooklyn                Fort Greene
# 14                       Sing           Manhattan                East Harlem
# 15                      Chaya            Brooklyn               Williamsburg
# 16                   Nathalie            Brooklyn         Bedford-Stuyvesant
# 17                    Gregory            Brooklyn            Windsor Terrace
# 18            Claude & Sophie           Manhattan                     Inwood
# 19                       Dana           Manhattan               East Village
# 20                       Teri           Manhattan                     Harlem
# 21                     Angela            Brooklyn         Bedford-Stuyvesant
# 22                     Laurie            Brooklyn                South Slope
# 23                    Harriet            Brooklyn                   Flatbush
# 24                        Ben           Manhattan            Lower East Side
# 25                     Edward           Manhattan               East Village
# 26                       Earl           Manhattan                     Harlem
# 27                       Rana            Brooklyn  Prospect-Lefferts Gardens
# 28                    Orestes              Queens           Long Island City
# 29                   Adreinne            Brooklyn         Bedford-Stuyvesant
# ...                       ...                 ...                        ...
# 46497                     Olu              Queens                   Rosedale
# 46498                   Caron               Bronx                  Wakefield
# 46499                   Tammy           Manhattan                     Harlem
# 46500                   Elena           Manhattan                Murray Hill
# 46501  Incentra Village Hotel           Manhattan                    Chelsea
# 46502  Incentra Village Hotel           Manhattan                    Chelsea
# 46503  Incentra Village Hotel           Manhattan                    Chelsea
# 46504                   Laura           Manhattan                  Chinatown
# 46505                   Gabby            Brooklyn                   Bushwick
# 46506                 Siobhan           Manhattan            Upper West Side
# 46507                 Jessica            Brooklyn               Vinegar Hill
# 46508                   David           Manhattan                     Nolita
# 46509            Sonder (NYC)           Manhattan         Financial District
# 46510               Elisabeth            Brooklyn              Crown Heights
# 46511            Sonder (NYC)           Manhattan         Financial District
# 46512            Sonder (NYC)           Manhattan         Financial District
# 46513         Angelo + Amirah            Brooklyn               Williamsburg
# 46514                   Tamar              Queens                  Rego Park
# 46515          Lorena & Mario           Manhattan                     Nolita
# 46516                 Kendall           Manhattan         Financial District
# 46517                    Omer            Brooklyn               Williamsburg
# 46518               Elisabeth            Brooklyn              Crown Heights
# 46519         Michael + Josué            Brooklyn               Clinton Hill
# 46520                    Elia              Queens                 St. Albans
# 46521                  Ashley           Manhattan                    Chelsea
# 46522                   Brian           Manhattan                   Gramercy
# 46523                   Salar           Manhattan         Washington Heights
# 46524                  Nicole            Brooklyn              East Flatbush
# 46525                Fernando           Manhattan            Upper West Side
# 46526                  Marina            Brooklyn                  Gravesend
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0      40.75362  -73.98377  Entire home/apt    175               3
# 1      40.68514  -73.95976  Entire home/apt     75               1
# 2      40.68688  -73.95596     Private room     60              29
# 3      40.66120  -73.99423  Entire home/apt    175              14
# 4      40.76489  -73.98493     Private room     65               2
# 5      40.80178  -73.96723     Private room     75               2
# 6      40.71344  -73.99037  Entire home/apt    140               1
# 7      40.73552  -74.01042  Entire home/apt    160               3
# 8      40.66829  -73.98779     Private room     88               4
# 9      40.79826  -73.96113     Private room     85               2
# 10     40.73530  -74.00525  Entire home/apt     65              30
# 11     40.70837  -73.95352  Entire home/apt    109               2
# 12     40.78962  -73.94802  Entire home/apt    239               4
# 13     40.69121  -73.97277  Entire home/apt    182               1
# 14     40.79685  -73.94872     Private room     96              14
# 15     40.71842  -73.95718  Entire home/apt    299               3
# 16     40.68371  -73.94028  Entire home/apt    120               2
# 17     40.65599  -73.97519     Private room    135               1
# 18     40.86754  -73.92639     Private room     86               4
# 19     40.72920  -73.98542  Entire home/apt    220               3
# 20     40.81305  -73.95466     Private room     55               2
# 21     40.68310  -73.95473     Private room     70               3
# 22     40.66869  -73.98780     Private room     88               4
# 23     40.63702  -73.96327     Private room    150               1
# 24     40.71401  -73.98917      Shared room     40               1
# 25     40.72290  -73.98199     Private room     40               2
# 26     40.81175  -73.94478  Entire home/apt    150               7
# 27     40.65944  -73.96238  Entire home/apt     95              30
# 28     40.74771  -73.94740     Private room    130               2
# 29     40.68111  -73.95591  Entire home/apt    100               5
# ...         ...        ...              ...    ...             ...
# 46497  40.65192  -73.74515     Private room     70               1
# 46498  40.88655  -73.86012     Private room    152               2
# 46499  40.81543  -73.94143  Entire home/apt    250               5
# 46500  40.74541  -73.97361  Entire home/apt    381               4
# 46501  40.75049  -73.99528     Private room     62               1
# 46502  40.74834  -73.99656     Private room     62               1
# 46503  40.74922  -73.99714     Private room     62               1
# 46504  40.71702  -73.99069  Entire home/apt    124               1
# 46505  40.69874  -73.93696     Private room     96               1
# 46506  40.79261  -73.97671  Entire home/apt    400               4
# 46507  40.70358  -73.98217     Private room    201               5
# 46508  40.72289  -73.99400  Entire home/apt    140              30
# 46509  40.70454  -74.01647  Entire home/apt   1806               2
# 46510  40.67156  -73.91651     Private room     61              30
# 46511  40.70439  -74.01470  Entire home/apt   1806               2
# 46512  40.70469  -74.01473  Entire home/apt    169               2
# 46513  40.71283  -73.95400  Entire home/apt    180               7
# 46514  40.71973  -73.86140     Private room     45               7
# 46515  40.72035  -73.99436  Entire home/apt    175               7
# 46516  40.70629  -74.00588     Private room     60             120
# 46517  40.71970  -73.95632     Private room     55              14
# 46518  40.67302  -73.91695     Private room     61              30
# 46519  40.69034  -73.96179  Entire home/apt    253              30
# 46520  40.69980  -73.77104     Private room     44               1
# 46521  40.74698  -73.99512  Entire home/apt    140               7
# 46522  40.73433  -73.98383  Entire home/apt    145               7
# 46523  40.85820  -73.92733  Entire home/apt     87               6
# 46524  40.65399  -73.93287     Private room     59               3
# 46525  40.78731  -73.97029  Entire home/apt     80              30
# 46526  40.59945  -73.98209     Private room     66               1
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                     48  2019-11-04               0.37
# 1                    340  2020-08-01               4.75
# 2                     50  2019-12-02               0.37
# 3                      1  2014-01-02               0.01
# 4                    473  2020-03-15               3.44
# 5                    118  2017-07-21               0.89
# 6                    161  2019-07-29               1.21
# 7                     66  2019-08-10               0.49
# 8                    180  2020-03-18               1.31
# 9                    123  2019-12-09               0.90
# 10                    29  2020-07-25               0.22
# 11                   181  2020-03-16               1.32
# 12                   233  2019-12-09               1.77
# 13                   229  2020-07-20               1.78
# 14                     0         NaN                NaN
# 15                     9  2011-12-28               0.07
# 16                   115  2020-08-13               0.86
# 17                    23  2019-10-14               0.84
# 18                     0         NaN                NaN
# 19                    33  2019-11-11               0.25
# 20                    98  2020-03-14               1.30
# 21                    75  2019-10-12               0.60
# 22                   180  2020-08-03               1.36
# 23                     0         NaN                NaN
# 24                   219  2019-11-13               1.67
# 25                   262  2020-03-17               1.99
# 26                   107  2019-12-07               0.83
# 27                    13  2019-12-05               0.36
# 28                   280  2020-03-15               2.26
# 29                    66  2020-03-02               0.51
# ...                  ...         ...                ...
# 46497                  0         NaN                NaN
# 46498                  0         NaN                NaN
# 46499                  0         NaN                NaN
# 46500                  0         NaN                NaN
# 46501                  0         NaN                NaN
# 46502                  0         NaN                NaN
# 46503                  0         NaN                NaN
# 46504                  0         NaN                NaN
# 46505                  0         NaN                NaN
# 46506                  0         NaN                NaN
# 46507                  0         NaN                NaN
# 46508                  0         NaN                NaN
# 46509                  0         NaN                NaN
# 46510                  0         NaN                NaN
# 46511                  0         NaN                NaN
# 46512                  0         NaN                NaN
# 46513                  0         NaN                NaN
# 46514                  0         NaN                NaN
# 46515                  0         NaN                NaN
# 46516                  0         NaN                NaN
# 46517                  0         NaN                NaN
# 46518                  0         NaN                NaN
# 46519                  0         NaN                NaN
# 46520                  0         NaN                NaN
# 46521                  0         NaN                NaN
# 46522                  0         NaN                NaN
# 46523                  0         NaN                NaN
# 46524                  0         NaN                NaN
# 46525                  0         NaN                NaN
# 46526                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  adjusted_price
# 0                                   2               365             175
# 1                                   1               265              75
# 2                                   1               365              60
# 3                                   1               295             175
# 4                                   1               340              65
# 5                                   1                 0              75
# 6                                   4               274             140
# 7                                   1               178             160
# 8                                   3               344              88
# 9                                   1               365              85
# 10                                  1               197              65
# 11                                  1                 0             209
# 12                                  1               365             239
# 13                                  2               325             182
# 14                                  2               178              96
# 15                                  1               337             399
# 16                                  2               319             120
# 17                                  2                89             135
# 18                                  1                 0              86
# 19                                  1                90             220
# 20                                  1               354              55
# 21                                  2               365              70
# 22                                  3               365              88
# 23                                  1               365             150
# 24                                  4               226              40
# 25                                  2                46              40
# 26                                  1               364             150
# 27                                  1               156              95
# 28                                  1               246             130
# 29                                  1                19             100
# ...                               ...               ...             ...
# 46497                               2               139              70
# 46498                               1               354             152
# 46499                               7               364             250
# 46500                               1               360             381
# 46501                              36               364              62
# 46502                              36               362              62
# 46503                              36               365              62
# 46504                               1               321             124
# 46505                               1               174              96
# 46506                               1                 4             400
# 46507                               1                45             201
# 46508                               1               282             140
# 46509                              43               337            1806
# 46510                               5               329              61
# 46511                              43               337            1806
# 46512                              43               337             169
# 46513                               1               364             280
# 46514                               1               359              45
# 46515                               1               364             175
# 46516                               1               349              60
# 46517                               1                45             155
# 46518                               5               363              61
# 46519                               1                74             253
# 46520                               1               161              44
# 46521                               1               358             140
# 46522                               1               164             145
# 46523                               2                85              87
# 46524                               1                90              59
# 46525                               1               113              80
# 46526                               1                38              66
#
# [46527 rows x 17 columns]

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  
select_condition1 = df["room_type"] == "Private room"
select_condition2 = df["room_type"] == "Shared room"

print("% of "+str( (df["room_type"][select_condition1].value_counts() / len(df)) *100))
print("% of "+str( (df["room_type"][select_condition2].value_counts() / len(df)) *100))
# Out:
# % of Private room    45.444581
# Name: room_type, dtype: float64
# % of Shared room    2.121349
# Name: room_type, dtype: float64

# %%
#Challenge
df[df["name"].str.contains("brownstone",na = False, case = False)]
# Out:
#              id                                               name    host_id  \
# 29        12940                 Charming Brownstone 3 - Near PRATT      50148
# 32        13394                             Fort Greene brownstone      52335
# 34        13808    Blue Room for 2 in Brownstone for $1350 monthly      54275
# 70        20717                   Room in Brownstone B/Q feet away      78353
# 92        27006    Comfortable UWS 2-BD Family-Friendly Brownstone     115560
# 125       38663                   Luxury Brownstone in Boerum Hill     165789
# 146       45910                 Beautiful Queens Brownstone! - 5BR     204539
# 151       46911     Large Room in private Brownstone in Park Slope     210746
# 171       55498  Modern comfort in art infused landmark Brownstone     262138
# 180       57874                 The Brownstone-Luxury 1 Bd Apt/NYC     276291
# 190       60193                      The Cozy Brownstone in Harlem     289838
# 203       62430                      BROWNSTONE SUNDRENCHED BEAUTY     197755
# 304      100368  Greenwich Village Brownstone -- Huge Private Deck     526105
# 306      102995                   UWS Brownstone Near Central Park     178043
# 355      141335                             Architect's Brownstone     687361
# 377      152263                     Cozy apartment in a brownstone     732535
# 387      159749  Purple Room for 2/3 in brownstone $1450 per month      54275
# 388      159815        Red Room for two in Brownstone for $1355/mo      54275
# 398      165080                Amazing Brownstone in Best Brooklyn     618702
# 437      189787                     Spacious & Comfy BK Brownstone     915640
# 439      190968                    Lovely Brooklyn Brownstone 1BR!     922922
# 463      205485                Ideal Brooklyn Brownstone Apartment    1010242
# 467      206473          FURNISHED BROWNSTONE DUPLEX in PARK SLOPE     888420
# 505      228925                               Beautiful Brownstone    1194377
# 544      245574                      Brooklyn Brownstone apartment    1288460
# 548      248717                Brownstone comfort + beautiful yard    1269526
# 657      276317  The Carlton, Brooklyn brownstone Duplex w/ garden     130901
# 683      286838                         Private Room in Brownstone    1492339
# 686      287421                 Cozy, Clean Cobble Hill Brownstone    1495141
# 774      342995     Unique private room and bathroom in Brownstone    1740216
# ...         ...                                                ...        ...
# 43783  43071163    Beautiful 1br in UWS brownstone on Central Park    4335378
# 43843  43103808                          Beautiful Brownstone Apt.   79720116
# 43848  43105265         Sun Drenched Duplex in Bed Stuy Brownstone    2065732
# 44009  43170693              Brownstone Living with amazing Views!  254420231
# 44109  43220447   Brooklyn's Best- Sunny & Spacious Brownstone Apt  238380801
# 44243  43299277   Airy Brooklyn Brownstone - 20% off monthly stays   10782510
# 44400  43367498              Huge light-filled historic brownstone   43232214
# 44591  43457355  Monthly Stay: Large brownstone 1bed, summer he...    4401257
# 44612  43466988            Modern brownstone apartment with garden    9407935
# 44667  43498999    Gorgeous Bohemian Duplex in Historic Brownstone      66286
# 44735  43546378  Cozy zen sanctuary w/ garden I Brooklyn browns...   18895623
# 45079  43766271            Hip and Historic Harlem Brownstone Apt.   60063052
# 45100  43778233  Park Slope 2 BD Brownstone Apt with Private Ga...    1826093
# 45149  43813411     Luxury apt in a Brownstone in Sobro, The Bronx   74024064
# 45176  43824388       Beautiful Brownstone apartment in Park Slope  350484704
# 45184  43831018               Park Slope Brownstone - entire floor    7478124
# 45227  43862926          Sunny 2BR in Historic Bed-Stuy Brownstone    5684621
# 45294  43906386    Brooklyn brownstone on quiet, tree-lined block.    9742120
# 45335  43928399                      One Bedroom Brownstone Beauty    9717514
# 45571  44073380  Brownstone Studio w/Loft Bedroom by Ft Greene ...  322423295
# 45656  44154139      Modern Equipped Studio in Bed Stuy Brownstone   49293531
# 45743  44210249             Brooklyn brownstone with outdoor space   13098239
# 45866  44304516   Central Park Brownstone studio & Private terrace    2644100
# 45988  44363142    Beautiful, serene brownstone with outdoor space   16256520
# 46191  44503706        Huge 1 Bed in a Private Historic Brownstone  209279462
# 46220  44531911               Private 2 Bed in Historic Brownstone  209279462
# 46337  44625524    Renovated Brownstone w/ Yard Near Prospect Park    2771914
# 46349  44631837   Unique and Stylish Park Slope Brownstone triplex   40231738
# 46390  44658559  Clean Room w/ Outdoor Deck in Brooklyn Brownstone    4393745
# 46401  44661851             Luxury Nest in the Sky in a Brownstone  100671934
#
#             host_name neighbourhood_group       neighbourhood  latitude  \
# 29           Adreinne            Brooklyn  Bedford-Stuyvesant  40.68111
# 32          Alexander            Brooklyn         Fort Greene  40.69142
# 34     JT And Tiziana            Brooklyn  Bedford-Stuyvesant  40.68064
# 70          Guillaume            Brooklyn    Prospect Heights  40.67832
# 92              Stacy           Manhattan     Upper West Side  40.77823
# 125             Sarah            Brooklyn         Boerum Hill  40.68559
# 146              Mark              Queens           Ridgewood  40.70382
# 151       Kathleen R.            Brooklyn    Prospect Heights  40.67868
# 171              Tami            Brooklyn  Bedford-Stuyvesant  40.68290
# 180             Simon           Manhattan              Harlem  40.80931
# 190            Zakiya           Manhattan              Harlem  40.80481
# 203            Sheila            Brooklyn            Bushwick  40.68800
# 304             Scott           Manhattan             Chelsea  40.74056
# 306              Chas           Manhattan     Upper West Side  40.78558
# 355              Orna            Brooklyn          Park Slope  40.67535
# 377           William           Manhattan              Harlem  40.80497
# 387    JT And Tiziana            Brooklyn  Bedford-Stuyvesant  40.68048
# 388    JT And Tiziana            Brooklyn  Bedford-Stuyvesant  40.68048
# 398            Smadar            Brooklyn     Carroll Gardens  40.68090
# 437          Sundiata            Brooklyn       Crown Heights  40.66788
# 439             Karen            Brooklyn    Prospect Heights  40.67946
# 463      Zora & Chris            Brooklyn  Bedford-Stuyvesant  40.68186
# 467               Ted            Brooklyn          Park Slope  40.67127
# 505         Marceline            Brooklyn  Bedford-Stuyvesant  40.67964
# 544               Al-            Brooklyn  Bedford-Stuyvesant  40.68890
# 548               Amy            Brooklyn          Park Slope  40.67360
# 657          Chauncey            Brooklyn    Prospect Heights  40.67847
# 683             Karin           Manhattan              Harlem  40.80748
# 686              Keow            Brooklyn         Cobble Hill  40.68538
# 774             Laura           Manhattan              Harlem  40.81169
# ...               ...                 ...                 ...       ...
# 43783       Madeleine           Manhattan     Upper West Side  40.78692
# 43843           Cheri           Manhattan              Harlem  40.80727
# 43848          Nicole            Brooklyn  Bedford-Stuyvesant  40.68531
# 44009           Efron            Brooklyn  Bedford-Stuyvesant  40.69039
# 44109        Brooklyn            Brooklyn         Fort Greene  40.68801
# 44243           Calen            Brooklyn        Clinton Hill  40.68726
# 44400        Nicholas            Brooklyn  Bedford-Stuyvesant  40.68067
# 44591       Elizabeth            Brooklyn         Boerum Hill  40.68690
# 44612        Benjamin            Brooklyn     Carroll Gardens  40.68046
# 44667            Liat            Brooklyn  Bedford-Stuyvesant  40.68487
# 44735   Nick & Eunice            Brooklyn  Bedford-Stuyvesant  40.68340
# 45079            Lori           Manhattan              Harlem  40.82702
# 45100            Jack            Brooklyn          Park Slope  40.67144
# 45149         Michael               Bronx         Hunts Point  40.81550
# 45176           Marie            Brooklyn          Park Slope  40.67610
# 45184            Igor            Brooklyn          Park Slope  40.67547
# 45227          Maggie            Brooklyn  Bedford-Stuyvesant  40.68945
# 45294         Jeffrey            Brooklyn         Sunset Park  40.64669
# 45335      Jacqueline            Brooklyn         Sunset Park  40.65360
# 45571         Michele            Brooklyn         Fort Greene  40.69104
# 45656           Aliza            Brooklyn  Bedford-Stuyvesant  40.68416
# 45743           Blair            Brooklyn        Clinton Hill  40.68451
# 45866            Jojo           Manhattan     Upper West Side  40.77929
# 45988        Rochelle            Brooklyn  Bedford-Stuyvesant  40.68302
# 46191         Rodrigo           Manhattan         East Harlem  40.79949
# 46220         Rodrigo           Manhattan         East Harlem  40.79928
# 46337             Ian            Brooklyn     Windsor Terrace  40.65772
# 46349        Thatcher            Brooklyn          Park Slope  40.67032
# 46390          Nelson            Brooklyn  Bedford-Stuyvesant  40.68289
# 46401          Fannie           Manhattan   Greenwich Village  40.73145
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 29     -73.95591  Entire home/apt    100               5                 66
# 32     -73.97376     Private room     70               1                143
# 34     -73.94039     Private room     81               2                141
# 70     -73.97243     Private room     85               1                 43
# 92     -73.97637  Entire home/apt    225               6                 28
# 125    -73.98094  Entire home/apt    650               3                 23
# 146    -73.89797  Entire home/apt    339               4                 13
# 151    -73.97307     Private room    100               3                 51
# 171    -73.93549     Private room     79              14                 42
# 180    -73.94343  Entire home/apt    157               3                258
# 190    -73.94777     Private room    150               3                  2
# 203    -73.91710  Entire home/apt     72               7                129
# 304    -74.00143  Entire home/apt    299              31                 32
# 306    -73.96960  Entire home/apt    212              21                 45
# 355    -73.97654  Entire home/apt    685               1                 35
# 377    -73.95016  Entire home/apt    300               2                229
# 387    -73.93938     Private room     87               2                 76
# 388    -73.93938     Private room     78               7                 51
# 398    -73.99233  Entire home/apt    500               7                  7
# 437    -73.94813  Entire home/apt    108               4                103
# 439    -73.96501  Entire home/apt    215               3                 37
# 463    -73.94113  Entire home/apt    145               3                135
# 467    -73.97985  Entire home/apt    175              90                  7
# 505    -73.93946  Entire home/apt    100              30                 10
# 544    -73.95383  Entire home/apt     80               2                185
# 548    -73.98113     Private room     65               1                 14
# 657    -73.97038  Entire home/apt    550               3                105
# 683    -73.95589     Private room     75               2                101
# 686    -74.00056  Entire home/apt    140               3                103
# 774    -73.94355     Private room     90               2                 88
# ...          ...              ...    ...             ...                ...
# 43783  -73.96869  Entire home/apt     87               6                  1
# 43843  -73.95054  Entire home/apt     90              30                  0
# 43848  -73.94517  Entire home/apt    155               3                  0
# 44009  -73.94224  Entire home/apt    171               1                  8
# 44109  -73.97699  Entire home/apt    124               3                  1
# 44243  -73.96286  Entire home/apt    150               1                  1
# 44400  -73.93423  Entire home/apt    200              14                  0
# 44591  -73.98666  Entire home/apt     75              30                  1
# 44612  -73.99905  Entire home/apt    250              29                  0
# 44667  -73.94075  Entire home/apt    150               1                  0
# 44735  -73.92770  Entire home/apt    100              30                  1
# 45079  -73.94235  Entire home/apt    149              31                  0
# 45100  -73.97444  Entire home/apt    275               4                  0
# 45149  -73.88694  Entire home/apt     98               1                 19
# 45176  -73.97388  Entire home/apt    160               5                  0
# 45184  -73.97667  Entire home/apt    165               3                  2
# 45227  -73.95428  Entire home/apt     95               7                  2
# 45294  -74.00790  Entire home/apt    110               7                  0
# 45335  -74.00493  Entire home/apt    150               3                  0
# 45571  -73.96955  Entire home/apt     75              28                  0
# 45656  -73.92762  Entire home/apt     90              14                  1
# 45743  -73.96213  Entire home/apt    144              14                  0
# 45866  -73.98380  Entire home/apt    110              10                  0
# 45988  -73.95782  Entire home/apt    500               4                  0
# 46191  -73.93550  Entire home/apt     88               3                  0
# 46220  -73.93514  Entire home/apt    144               3                  0
# 46337  -73.97696  Entire home/apt    995               5                  0
# 46349  -73.98052  Entire home/apt    400              30                  0
# 46390  -73.95348     Private room     40               4                  0
# 46401  -73.99466  Entire home/apt    532              29                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 29     2020-03-02               0.51                               1
# 32     2020-03-19               1.11                               1
# 34     2020-07-12               1.14                               3
# 70     2020-03-17               0.52                               3
# 92     2019-07-12               0.25                               1
# 125    2018-12-31               0.23                               1
# 146    2019-11-12               0.12                               5
# 151    2019-06-24               0.42                               3
# 171    2020-03-15               0.36                               1
# 180    2020-08-07               2.17                               2
# 190    2011-08-29               0.02                               1
# 203    2020-02-07               1.97                               1
# 304    2019-07-05               0.29                               1
# 306    2018-01-01               0.40                               1
# 355    2018-01-13               0.35                               1
# 377    2020-03-08               2.11                               3
# 387    2020-01-03               0.71                               3
# 388    2020-03-01               0.47                               3
# 398    2018-08-29               0.06                               1
# 437    2020-01-01               0.94                               1
# 439    2019-12-28               0.34                               1
# 463    2020-01-03               1.24                               1
# 467    2014-05-27               0.09                               1
# 505    2019-06-26               0.48                               1
# 544    2020-05-24               1.72                               1
# 548    2020-03-08               0.13                               2
# 657    2020-03-15               1.00                               1
# 683    2015-10-31               0.96                               1
# 686    2017-08-01               0.99                               1
# 774    2019-11-30               0.87                               2
# ...           ...                ...                             ...
# 43783  2020-05-13               0.32                               1
# 43843         NaN                NaN                               1
# 43848         NaN                NaN                               1
# 44009  2020-07-25               2.82                               1
# 44109  2020-07-31               1.00                               1
# 44243  2020-06-24               0.56                               1
# 44400         NaN                NaN                               1
# 44591  2020-08-04               1.00                               1
# 44612         NaN                NaN                               1
# 44667         NaN                NaN                               3
# 44735  2020-07-11               0.81                               1
# 45079         NaN                NaN                               1
# 45100         NaN                NaN                               1
# 45149  2020-08-12               9.66                               1
# 45176         NaN                NaN                               1
# 45184  2020-07-12               1.30                               1
# 45227  2020-07-24               1.50                               1
# 45294         NaN                NaN                               1
# 45335         NaN                NaN                               1
# 45571         NaN                NaN                               1
# 45656  2020-08-08               1.00                               4
# 45743         NaN                NaN                               1
# 45866         NaN                NaN                               1
# 45988         NaN                NaN                               1
# 46191         NaN                NaN                               3
# 46220         NaN                NaN                               3
# 46337         NaN                NaN                               1
# 46349         NaN                NaN                               2
# 46390         NaN                NaN                               1
# 46401         NaN                NaN                               2
#
#        availability_365  adjusted_price
# 29                   19             100
# 32                  170              70
# 34                  339              81
# 70                  312              85
# 92                  337             225
# 125                 365             650
# 146                 365             339
# 151                 229             100
# 171                 108              79
# 180                 319             157
# 190                 365             150
# 203                   0              72
# 304                 349             299
# 306                  44             212
# 355                 365             685
# 377                 325             300
# 387                 348              87
# 388                 322              78
# 398                   0             500
# 437                   0             108
# 439                 177             215
# 463                 227             145
# 467                  57             175
# 505                 363             100
# 544                 311              80
# 548                 364              65
# 657                 365             550
# 683                   0              75
# 686                 228             140
# 774                 179              90
# ...                 ...             ...
# 43783                 0              87
# 43843               365              90
# 43848                88             155
# 44009               227             171
# 44109               338             124
# 44243                 8             150
# 44400               103             200
# 44591                70              75
# 44612               108             250
# 44667                 0             150
# 44735                71             100
# 45079               365             149
# 45100               250             275
# 45149               164              98
# 45176               112             160
# 45184                20             165
# 45227               227              95
# 45294                 0             110
# 45335               336             150
# 45571                 6              75
# 45656               261              90
# 45743                30             144
# 45866               173             110
# 45988                26             500
# 46191               358              88
# 46220               355             144
# 46337                23             995
# 46349               265             400
# 46390                74              40
# 46401               178             532
#
# [1118 rows x 17 columns]

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
df.groupby('neighbourhood_group')["id"].count()
# Out:
# neighbourhood_group
# Bronx             1183
# Brooklyn         18632
# Manhattan        20580
# Queens            5791
# Staten Island      341
# Name: id, dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 
df.groupby('neighbourhood_group')["price"].mean()
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 
df.groupby('neighbourhood_group')['price'].agg(['min', 'max'])
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.
df.groupby(['neighbourhood_group','room_type'])["price"].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt    138.004819
#                      Private room        68.419668
#                      Shared room         66.391304
# Brooklyn             Entire home/apt    171.587687
#                      Hotel room         147.300000
#                      Private room        71.291189
#                      Shared room         57.870091
# Manhattan            Entire home/apt    231.335572
#                      Hotel room         292.515670
#                      Private room       128.277069
#                      Shared room        111.735084
# Queens               Entire home/apt    150.168900
#                      Hotel room         139.058824
#                      Private room        69.972564
#                      Shared room         89.891892
# Staten Island        Entire home/apt    151.720930
#                      Private room        70.312883
#                      Shared room         46.000000
# Name: price, dtype: float64

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.
gbList = ['neighbourhood_group','room_type']
df.groupby(gbList)["price"].agg( ["count","min","max","mean","median","std"] )
# Out:
#                                      count  min    max        mean  median  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    415   25   1404  138.004819     103
#                     Private room       722   16    700   68.419668      55
#                     Shared room         46   20    800   66.391304      44
# Brooklyn            Entire home/apt   9112   20  10000  171.587687     135
#                     Hotel room          30    0    399  147.300000     129
#                     Private room      9159   10   2500   71.291189      60
#                     Shared room        331   15   1500   57.870091      36
# Manhattan           Entire home/apt  12209    0  10000  231.335572     165
#                     Hotel room         351    0   2211  292.515670     210
#                     Private room      7601   10  10000  128.277069      80
#                     Shared room        419   10  10000  111.735084      60
# Queens              Entire home/apt   2090   10  10000  150.168900     115
#                     Hotel room          17    0    249  139.058824     149
#                     Private room      3499   18   9000   69.972564      55
#                     Shared room        185   14   3000   89.891892      40
# Staten Island       Entire home/apt    172   39   1200  151.720930     111
#                     Private room       163   20    800   70.312883      55
#                     Shared room          6   19     82   46.000000      38
#
#                                             std
# neighbourhood_group room_type
# Bronx               Entire home/apt  126.032106
#                     Private room      57.337866
#                     Shared room      114.442703
# Brooklyn            Entire home/apt  236.732843
#                     Hotel room        91.153206
#                     Private room      69.023165
#                     Shared room       92.217618
# Manhattan           Entire home/apt  410.306439
#                     Hotel room       315.924085
#                     Private room     448.677306
#                     Shared room      502.728868
# Queens              Entire home/apt  252.606739
#                     Hotel room        50.743806
#                     Private room     163.814468
#                     Shared room      275.675158
# Staten Island       Entire home/apt  147.518392
#                     Private room      70.759593
#                     Shared room       28.446441

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
pricesDF = pd.read_csv('data/prices.csv', sep=',')
nlistingsDF = pd.read_csv('data/n_listings.csv', sep=';')

# %%
# 2. Do join that keeps all the records for each table.
mergeDF = pd.merge(pricesDF, nlistingsDF, on='neighbourhood_group', how='outer')

save_as = 'joined.csv'

mergeDF.to_csv(save_as, index=False)

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
#  1. Who was won Album of the Year in 2016?
grammyDF = pd.read_csv('data/grammys.csv',sep=",")
select = grammyDF["category"] == "Album of the Year"
select2 = grammyDF["year"] == 2016
select3 = grammyDF["winner"] == True

print(grammyDF[select & select2 & select3]["workers"].to_string())
# Out:
# 5505    Taylor Swift (artist/producer), Jack Antonoff ...

# %%
# 2. Who won Best Rap Album in 2009?
select = grammyDF["category"] == "Best Rap Album"
select2 = grammyDF["year"] == 2009
select3 = grammyDF["winner"] == True

print(grammyDF[select & select2 & select3]["workers"].to_string())
# Out:
# 4396    Lil' Wayne

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?
select1 = grammyDF["workers"].isin( ["Kendrick Lamar"] )
select2 = grammyDF["winner"] == True
print("Nomination: "+str(grammyDF[select1]["winner"].count()))
grammyDF[select1]
# Out:
# Nomination: 6
#       year              category                  nominee         workers  \
# 5269  2014        Best Rap Album  Good Kid, M.A.A.D City.  Kendrick Lamar
# 5272  2014  Best Rap Performance  Swimming Pools (Drank).  Kendrick Lamar
# 5448  2015  Best Rap Performance                       i.  Kendrick Lamar
# 5596  2016        Best Rap Album     To Pimp a Butterfly.  Kendrick Lamar
# 5599  2016  Best Rap Performance                 Alright.  Kendrick Lamar
# 6003  2018  Best Rap Performance                  HUMBLE.  Kendrick Lamar
#
#       winner
# 5269   False
# 5272   False
# 5448    True
# 5596    True
# 5599    True
# 6003    True

# %%
print("Winner: "+str(grammyDF[select1 & select2]["winner"].count()))
grammyDF[select1 & select2]
# Out:
# Winner: 4
#       year              category               nominee         workers  winner
# 5448  2015  Best Rap Performance                    i.  Kendrick Lamar    True
# 5596  2016        Best Rap Album  To Pimp a Butterfly.  Kendrick Lamar    True
# 5599  2016  Best Rap Performance              Alright.  Kendrick Lamar    True
# 6003  2018  Best Rap Performance               HUMBLE.  Kendrick Lamar    True
